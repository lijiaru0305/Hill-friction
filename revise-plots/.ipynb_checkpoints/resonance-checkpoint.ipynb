# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size':22})

import warnings
warnings.filterwarnings('ignore')

# %%
fig,axs = plt.subplots(1,1, sharex=True, sharey=False, figsize=(12,8))
fig.subplots_adjust(hspace=0.0)

def min180To180(val):
    val = val%(2*np.pi)
    lindex = val<-np.pi
    rindex = val>+np.pi
    val = val + 2*np.pi*lindex - 2*np.pi*rindex
    return (val/np.pi)


def min0To360(val):
    val = val%(2*np.pi)
    return (val/np.pi)

for i in [3]:
    
    #p12_data = np.load('./data/res-res/m5K3%1d.npy'%i)
    #p12_data = np.load('./data/res-res/m5K33-se.npy')
    p12_data = np.load('./data/res-res/orbit_time_000.npy')
    #p12_data = np.load('./data/res-res/m4K32-noforce.npy')
    
    t = p12_data[:,0,0]
    de = p12_data[2:,1,2] - p12_data[:-2,1,2]
    phi = (p12_data[1:-1,1,5] - p12_data[1:-1,1,3])%(2*np.pi)
    dM = ((p12_data[:,0,5]%(2*np.pi) - p12_data[:,1,5]%(2*np.pi)))%(2*np.pi)
    #tmax = np.argmax(t[1:-1]==0)
    icon =( ((dM[2:]-dM[1:-1])*(dM[1:-1]-dM[:-2]))<0 ) * (t[1:-1]<1e1)
    #axs.scatter(phi[icon]/np.pi,de[icon],s=3)
    l0 = p12_data[:,0,5]
    l1 = p12_data[:,1,5]
    pm0 = p12_data[:,0,3] + p12_data[:,0,4]
    pm1 = p12_data[:,1,3] + p12_data[:,1,4]
    p = 13
    q = 1
    ang0 = (p+q)*l1 - p*l0 - q*pm0
    ang1 = (p+q)*l1 - p*l0 - q*pm1
    #ang0 = p12_data[:,5]
    #ang1 = p12_data[:,6]
    #axs.scatter(t, l1,s=1)
    #axs.scatter(t, min0To360(ang0),s=1)
    #axs.scatter(t, min180To180(ang1),s=1)
    #axs.plot(t, min180To180(ang1))
    #axs.set_ylim([-5,5])
    
    #axs.scatter(t, min0To360(ang1),s=1)
    #axs.set_xlim([0.990e5,1e5])
    
    ind_safe = np.abs(min180To180(l1-l0))>(1/180.)
    axs.scatter(t[ind_safe], min0To360(ang1[ind_safe]),s=0.0005)
    #axs.scatter(t, min0To360(pm0),s=1)
    #axs.scatter(t, min180To180(ang0))
    axs.set_xlim([0,1e5])
    axs.set_ylim([0,2])
    
    #axs.plot(t,min0To360(l0),min0To360(l1))
    #axs.axvline(x=1,c='k')
    #axs.plot(t,p12_data[:,0,1],p12_data[:,1,1])
    
    ind_conj = np.abs(min180To180(l1-l0))<(1/180.)
    print(np.sum(ind_conj)*13)
    axs.scatter(t[ind_conj], min0To360(ang1[ind_conj]),s=1)
    
    #axs.fill_between(t,y1=0.5,y2=1.5,color='k',alpha=0.1)
# Out:
# 90194

# %%
fig,axs = plt.subplots(1,1, sharex=True, sharey=False, figsize=(12,8))
fig.subplots_adjust(hspace=0.0)

def min180To180(val):
    val = val%(2*np.pi)
    lindex = val<-np.pi
    rindex = val>+np.pi
    val = val + 2*np.pi*lindex - 2*np.pi*rindex
    return (val/np.pi)


def min0To360(val):
    val = val%(2*np.pi)
    return (val/np.pi)

for i in [3]:
    
    #p12_data = np.load('./data/res-res/m5K3%1d.npy'%i)
    #p12_data = np.load('./data/res-res/m5K33-se.npy')
    p12_data = np.load('./data/res-res/orbit_time_000.npy')
    #p12_data = np.load('./data/res-res/m4K32-noforce.npy')
    
    t = p12_data[:,0,0]
    de = p12_data[2:,1,2] - p12_data[:-2,1,2]
    phi = (p12_data[1:-1,1,5] - p12_data[1:-1,1,3])%(2*np.pi)
    dM = ((p12_data[:,0,5]%(2*np.pi) - p12_data[:,1,5]%(2*np.pi)))%(2*np.pi)
    #tmax = np.argmax(t[1:-1]==0)
    icon =( ((dM[2:]-dM[1:-1])*(dM[1:-1]-dM[:-2]))<0 ) * (t[1:-1]<1e1)
    #axs.scatter(phi[icon]/np.pi,de[icon],s=3)
    l0 = p12_data[:,0,5]
    l1 = p12_data[:,1,5]
    pm0 = p12_data[:,0,3] + p12_data[:,0,4]
    pm1 = p12_data[:,1,3] + p12_data[:,1,4]
    p = 13
    q = 1
    ang0 = (p+q)*l1 - p*l0 - q*pm0
    ang1 = (p+q)*l1 - p*l0 - q*pm1
    #ang0 = p12_data[:,5]
    #ang1 = p12_data[:,6]
    #axs.scatter(t, l1,s=1)
    #axs.scatter(t, min0To360(ang0),s=1)
    #axs.scatter(t, min180To180(ang1),s=1)
    #axs.plot(t, min180To180(ang1))
    #axs.set_ylim([-5,5])
    
    #axs.scatter(t, min0To360(ang1),s=1)
    #axs.set_xlim([0.990e5,1e5])
    
    ind_conj = np.abs(min180To180(l1-l0))<(1.1/180.)
    #print(np.sum(ind_conj)*13)
    
    ind_safe = np.abs(min180To180(l1-l0))>(30/180.)
    #axs.scatter(t[ind_safe], p12_data[ind_safe,1,2],s=0.0005)
    #axs.scatter(t, min0To360(pm0),s=1)
    #axs.scatter(t, min180To180(ang0))
    #axs.set_xlim([0,1e3])
    
    de = np.diff(p12_data[ind_safe,1,2])
    tc = 0.5*(t[ind_safe][:-1]+t[ind_safe][1:])
    
    tc = tc[np.abs(de)>3.5e-5]
    de = de[np.abs(de)>3.5e-5]
    
    print(len(de))
    #xs.scatter(min0To360(np.interp(tc[np.abs(de)>1e-4],t,ang1)), de[np.abs(de)>1e-4],s=5)
    axs.scatter(tc,de,s=5)
    #axs.scatter(t, min0To360(pm0),s=1)
    #axs.scatter(t, min180To180(ang0))
    axs.set_xlim([0,1e5])
# Out:
# 7216
